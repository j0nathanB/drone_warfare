# %%
import pandas as pd
from thefuzz import process
import re
import dask.dataframe as dd
from dask.distributed import Client, LocalCluster
import multiprocessing as mp

DIR = "/Users/tlahtolli/dev/drone_warfare/data/cleanup"

# %%
af = pd.read_csv(f'{DIR}/3_manual_cleanup/af.csv',)
pk = pd.read_csv(f'{DIR}/3_manual_cleanup/pk.csv')
so = pd.read_csv(f'{DIR}/3_manual_cleanup/so.csv')
ye = pd.read_csv(f'{DIR}/3_manual_cleanup/ye.csv')

af_nga = pd.read_csv(f'{DIR}/nga/Afghanistan/Afghanistan.txt', sep='\t')
pk_nga = pd.read_csv(f'{DIR}/nga/Pakistan/Pakistan.txt', sep='\t')
so_nga = pd.read_csv(f'{DIR}/nga/Somalia/Somalia.txt', sep='\t')
ye_nga = pd.read_csv(f'{DIR}/nga/Yemen/Yemen.txt', sep='\t')

admin_nga = pd.read_csv(f'{DIR}/nga/Administrative_Regions/Administrative_Regions.txt', sep='\t')
# Out:
# /Users/tlahtolli/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3378: DtypeWarning: Columns (8,9,18,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/tlahtolli/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3378: DtypeWarning: Columns (8,9,13,16,17,18,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/tlahtolli/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3378: DtypeWarning: Columns (8,20,21,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/tlahtolli/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3378: DtypeWarning: Columns (7,8,9,17,18,20,21,23,30,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
class LocationNormalizer:
    def __init__(self, source_df, ref_df):
        self.source_df = source_df.copy()
        self.ref_df = ref_df.copy()
        self.target_df = None
        self.source_subset = None
        self.ref_subset = None
        self.adm1_codes = []

    def create_sort_name(self, name):
        name = re.sub(r'[^a-zA-Z0-9\s]', '', name)
        return name.upper().replace(' ', '')
    
    def create_sort_columns(self, df, col):
        df[f'sort_{col}'] = df[col].apply(self.create_sort_name)
        return df
    
    def get_unique_source_locations(self, df, col='Adm_1', adm1_code=None):
        unwanted_values = ["unknown", "unclear", "various", "multiple", 'Unknown', 'Unclear', 'Various', 'Multiple']
        filtered_df = df[~df[col].isin(unwanted_values) & df[col].notnull()]

        if adm1_code:
            adm1_col = 'matched_sort_Adm_1_adm1'
            filtered_df = filtered_df[filtered_df[adm1_col] == adm1_code]
        result = filtered_df[[col]].drop_duplicates()

        return result
    
    def get_unique_ref_location_data(self, desig_cd='ADM1', adm1_code=None):
        if desig_cd == '':
            filter_condition = (~self.ref_df['desig_cd'].isin(['ADM1', 'ADM2', 'ADM3', 'ADM4']))
        else:
            filter_condition = (self.ref_df['desig_cd'] == desig_cd) & (self.ref_df['name_rank'] == 1)

        if adm1_code:
            filter_condition &= (self.ref_df['adm1'] == adm1_code)

        unique_adm1_df = self.ref_df.loc[filter_condition, ['ufi', 'adm1', 'sort_name', 'full_name','full_nm_nd', 'desig_cd','lat_dd', 'long_dd']].drop_duplicates(subset=['sort_name'])
        return unique_adm1_df

    def fuzzy_search(self, query, choices):
        try:
            match = process.extractOne(query, choices)
            if match[1] >= 75:
                return match[0]
            else:
                return 'unclear'
        except:
            return 'unclear'
        

    def get_matches(self, source_subset, ref_subset, col='Adm_1'):
        target_col = f'matched_sort_{col}'
        # Rename the sort_name column to match the col
        ref_subset = ref_subset.rename(columns={'sort_name': f'{target_col}'})
        # Convert the Pandas DataFrames to Dask DataFrames
        source_ddf = dd.from_pandas(source_subset, npartitions=8)
        ref_ddf = dd.from_pandas(ref_subset, npartitions=8)

        def fuzzy_search_sort_name(query, ref_ddf):
            return self.fuzzy_search(query, ref_ddf[f'{target_col}'])

        # Apply the fuzzy search function on the source subset searching the reference subset
        source_ddf[f'{target_col}'] = source_ddf[f'sort_{col}'].apply(fuzzy_search_sort_name, ref_ddf=ref_ddf, meta=(f'{target_col}', 'object'))

        # Convert the Dask DataFrame back to a Pandas DataFrame
        source_df = source_ddf.compute()

        # Rename columns in ref_subset by prepending target_col
        renamed_columns = {col: f'{target_col}_{col}' for col in ref_subset.columns}
        ref_subset = ref_subset.rename(columns=renamed_columns)

        # Perform the left join between source_df and ref_subset
        result_df = pd.merge(source_df, ref_subset, left_on=f'{target_col}', right_on=f'{target_col}_{target_col}', how='left')
        
        # Return the original columns along with the matched columns
        return result_df[[col, *result_df.columns[result_df.columns.str.startswith(target_col)]]]


    def get_normalized_loc_data(self, col='Adm_1'):
        self.create_sort_columns(self.source_subset, col)

        normalized_names = self.get_matches(self.source_subset, self.ref_subset, col)
        return normalized_names

    def normalize(self, df, col="Adm_1", desig_cd='ADM1'):
        normalized_data = self.get_normalized_loc_data(col)
        merged_df = pd.merge(df, normalized_data, on=col, how='left', suffixes=('', '_matched'))

        # Update the original columns with matched values
        for col in df.columns:
            if f"{col}_matched" in merged_df.columns:
                # Update the original column with the matched values when they exist (i.e., not NaN)
                merged_df[col].update(merged_df[f"{col}_matched"].dropna())

        # Drop the extra columns created due to the merge
        cols_to_keep = [col for col in merged_df.columns if not col.endswith('_matched')]
        merged_df = merged_df[cols_to_keep]

        return merged_df

    def get_unique_adm1_codes(self, df):
        return df['matched_sort_Adm_1_adm1'].dropna().drop_duplicates().tolist()
    
    def prepare_data(self, df, col='Adm_1', desig_cd='ADM1', adm1_code=None):
        self.source_subset = self.get_unique_source_locations(df, col, adm1_code)
        self.ref_subset = self.get_unique_ref_location_data(desig_cd, adm1_code)

    def normalize_adm_1(self):
        self.prepare_data(self.source_df, 'Adm_1', 'ADM1')
        self.target_df = self.normalize(self.source_df, 'Adm_1', 'ADM1')
        self.adm1_codes = self.get_unique_adm1_codes(self.target_df)
    
    def normalize_remaining(self, col='Adm_2', desig_cd='ADM2'):
        for adm1_code in self.adm1_codes:
            self.prepare_data(self.target_df, col, desig_cd, adm1_code)
            self.target_df = self.normalize(self.target_df, col, desig_cd)

    def output(self, filename):
        self.target_df.to_csv(filename, index=False)

# %%
with LocalCluster(n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    memory_limit='2GB',
) as cluster, Client(cluster) as client:
    # Do something using 'client'
    af_norm = LocationNormalizer(af, af_nga)
    af_norm.normalize_adm_1()
    af_norm.normalize_remaining('Adm_2', 'ADM2')
    af_norm.normalize_remaining('Loc', '')
    af_norm.output(f'{DIR}/4_nga_normalize/af.csv')
    print('AF Done')

with LocalCluster(n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    memory_limit='2GB',
) as cluster, Client(cluster) as client:
    # Do something using 'client'
    pk_norm = LocationNormalizer(pk, pk_nga)
    pk_norm.normalize_adm_1()
    pk_norm.normalize_remaining('Adm_2', 'ADM2')
    pk_norm.normalize_remaining('Adm_3', 'ADM3')
    pk_norm.normalize_remaining('Adm_4', '') # not designated as ADM4 in NGA
    pk_norm.normalize_remaining('Loc', '')
    pk_norm.output(f'{DIR}/4_nga_normalize/pk.csv')
    print('PK Done')

with LocalCluster(n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    memory_limit='2GB',
) as cluster, Client(cluster) as client:
    # Do something using 'client'
    so_norm = LocationNormalizer(so, so_nga)
    so_norm.normalize_adm_1()
    so_norm.normalize_remaining('Adm_2', 'ADM2')
    so_norm.normalize_remaining('Loc', '')
    so_norm.output(f'{DIR}/4_nga_normalize/so.csv')
    print('SO Done')

with LocalCluster(n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    memory_limit='2GB',
) as cluster, Client(cluster) as client:
    # Do something using 'client'
    ye_norm = LocationNormalizer(ye, ye_nga)
    ye_norm.normalize_adm_1()
    ye_norm.normalize_remaining('Adm_2', 'ADM2')
    ye_norm.normalize_remaining('Loc', '')
    ye_norm.output(f'{DIR}/4_nga_normalize/ye.csv')
    print('YE Done')
# Out:
# 2023-03-21 21:31:39,316 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 696.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:31:39,377 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 699.17 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:31:43,120 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 655.63 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:31:47,978 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:58837 (pid=6697) exceeded 95% memory budget. Restarting...
# 2023-03-21 21:31:48,055 - distributed.nanny - WARNING - Restarting worker
# 2023-03-21 21:31:48,168 - distributed.nanny.memory - WARNING - Worker tcp://127.0.0.1:58834 (pid=6696) exceeded 95% memory budget. Restarting...
# 2023-03-21 21:31:48,172 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 680.25 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:31:48,260 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:58870 -> tcp://127.0.0.1:58834
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/distributed/worker.py", line 1797, in get_data
#     response = await comm.read(deserializers=serializers)
#   File "/usr/local/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/local/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:58870 remote=tcp://127.0.0.1:58899>: Stream is closed
# 2023-03-21 21:31:48,261 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:58834
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/distributed/comm/core.py", line 329, in connect
#     handshake = await wait_for(comm.read(), time_left())
#   File "/usr/local/lib/python3.9/site-packages/distributed/utils.py", line 1812, in wait_for
#     return await asyncio.wait_for(fut, timeout)
#   File "/usr/local/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/asyncio/tasks.py", line 481, in wait_for
#     return fut.result()
#   File "/usr/local/lib/python3.9/site-packages/distributed/comm/tcp.py", line 241, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/local/lib/python3.9/site-packages/distributed/comm/tcp.py", line 144, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:58930 remote=tcp://127.0.0.1:58834>: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/distributed/worker.py", line 2082, in gather_dep
#     response = await get_data_from_worker(
#   File "/usr/local/lib/python3.9/site-packages/distributed/worker.py", line 2901, in get_data_from_worker
#     comm = await rpc.connect(worker)
#   File "/usr/local/lib/python3.9/site-packages/distributed/core.py", line 1475, in connect
#     return await connect_attempt
#   File "/usr/local/lib/python3.9/site-packages/distributed/core.py", line 1396, in _connect
#     comm = await connect(
#   File "/usr/local/lib/python3.9/site-packages/distributed/comm/core.py", line 334, in connect
#     raise OSError(
# OSError: Timed out during handshake while connecting to tcp://127.0.0.1:58834 after 30 s
# 2023-03-21 21:31:48,491 - distributed.nanny - WARNING - Restarting worker
# 2023-03-21 21:31:48,858 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 592.13 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:31:53,412 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 704.00 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:31:54,476 - distributed.worker.memory - WARNING - Worker is at 90% memory usage. Pausing worker.  Process memory: 859.88 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:31:54,555 - distributed.worker.memory - WARNING - Worker is at 72% memory usage. Resuming worker. Process memory: 690.88 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:31:58,121 - distributed.worker.memory - WARNING - Worker is at 83% memory usage. Pausing worker.  Process memory: 792.95 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:31:58,289 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.26 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:03,511 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.89 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:08,296 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.27 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:13,610 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.89 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:18,396 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.27 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:23,711 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.89 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:28,496 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.27 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:33,810 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.89 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:38,595 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.27 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:43,810 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.89 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:48,696 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.27 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:53,810 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.90 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:32:58,795 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.27 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:03,910 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.90 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:08,796 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.27 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:14,011 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.90 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:18,895 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.27 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:24,011 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.90 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:28,995 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.28 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:34,110 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.90 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:38,995 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.28 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:44,111 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.90 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:49,096 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.29 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:54,210 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.91 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:33:59,196 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.29 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:04,309 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.91 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:09,296 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.29 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:14,310 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.91 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:19,396 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.29 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:24,310 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.91 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:29,495 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.29 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:34,410 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 690.94 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:39,595 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.29 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:44,510 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.01 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:49,595 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.29 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:54,511 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.01 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:34:59,695 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.29 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:04,610 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.01 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:09,696 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.32 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:14,611 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.01 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:19,796 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.34 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:24,710 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.02 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:29,896 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.36 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:34,810 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.02 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:39,996 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.39 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:44,810 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.02 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:49,996 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.41 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:35:54,811 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.02 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:00,095 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.44 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:04,911 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.02 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:10,095 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.48 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:15,010 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.03 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:20,195 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.50 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:25,110 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.03 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:30,195 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.53 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:35,110 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.03 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:40,196 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.54 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:45,110 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.03 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:50,196 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.54 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:36:55,210 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.03 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:00,296 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.54 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:05,210 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.04 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:10,296 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:15,310 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.04 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:20,418 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:25,410 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.04 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:30,496 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:35,510 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.04 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:40,595 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:45,510 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.05 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:50,596 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:37:55,610 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.09 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:00,696 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:05,711 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.10 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:10,795 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:15,810 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.13 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:20,796 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:25,810 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.15 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:30,895 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:35,910 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.18 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:40,995 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:46,010 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.20 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:50,996 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.56 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:38:56,109 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.20 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:01,095 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.56 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:06,110 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.21 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:11,195 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.56 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:16,209 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.21 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:21,295 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.56 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:26,210 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.21 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:31,295 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.56 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:36,310 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.21 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:41,395 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.56 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:46,409 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.21 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:51,396 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.56 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:39:56,410 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.21 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:01,496 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.56 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:06,510 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.21 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:11,596 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.56 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:16,610 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.21 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:21,596 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.57 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:26,710 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.22 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:31,596 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.57 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:36,809 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.22 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:41,716 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.57 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:46,810 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.22 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:51,795 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.57 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:40:56,909 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.22 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:41:01,796 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.57 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:41:07,010 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.22 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:41:11,796 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.57 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:41:17,109 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.22 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:41:21,895 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.57 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:41:27,209 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.23 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:41:31,996 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.57 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:41:37,210 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 691.24 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 21:41:42,095 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 881.57 MiB -- Worker memory limit: 0.93 GiB
# ...
# 2023-03-21 22:04:10,496 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 797.82 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:04:20,594 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 797.82 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:04:30,694 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 797.83 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:04:40,696 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 797.83 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:04:50,796 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 797.85 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:05:00,893 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 797.86 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:05:10,895 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 797.87 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:05:20,995 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 797.89 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:05:31,094 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.45 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:05:41,095 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.46 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:05:51,095 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.48 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:06:01,195 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.49 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:06:11,294 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.51 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:06:21,295 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.54 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:06:31,295 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.55 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:06:41,394 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.57 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:06:51,394 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.58 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:07:01,493 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.61 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:07:11,594 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.62 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:07:21,694 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.71 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:07:31,794 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.72 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:07:41,893 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.73 MiB -- Worker memory limit: 0.93 GiB
# 2023-03-21 22:07:51,893 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 798.75 MiB -- Worker memory limit: 0.93 GiB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb Cell 4 in 9
#       <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> af_norm = LocationNormalizer(af, af_nga)
#       <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> af_norm.normalize_adm_1()
# ----> <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> af_norm.normalize_remaining('Adm_2', 'ADM2')
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> af_norm.normalize_remaining('Loc', '')
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> af_norm.output(f'{DIR}/4_nga_normalize/af.csv')
#
# /Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb Cell 4 in 1
#     <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=114'>115</a> for adm1_code in self.adm1_codes:
#     <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=115'>116</a>     self.prepare_data(self.target_df, col, desig_cd, adm1_code)
# --> <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=116'>117</a>     self.target_df = self.normalize(self.target_df, col, desig_cd)
#
# /Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb Cell 4 in 8
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=85'>86</a> def normalize(self, df, col="Adm_1", desig_cd='ADM1'):
# ---> <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=86'>87</a>     normalized_data = self.get_normalized_loc_data(col)
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=87'>88</a>     merged_df = pd.merge(df, normalized_data, on=col, how='left', suffixes=('', '_matched'))
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=89'>90</a>     # Update the original columns with matched values
#
# /Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb Cell 4 in 8
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=79'>80</a> def get_normalized_loc_data(self, col='Adm_1'):
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=80'>81</a>     self.create_sort_columns(self.source_subset, col)
# ---> <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=82'>83</a>     normalized_names = self.get_matches(self.source_subset, self.ref_subset, col)
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=83'>84</a>     return normalized_names
#
# /Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb Cell 4 in 6
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=63'>64</a> source_ddf[f'{target_col}'] = source_ddf[f'sort_{col}'].apply(fuzzy_search_sort_name, ref_ddf=ref_ddf, meta=(f'{target_col}', 'object'))
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=65'>66</a> # Convert the Dask DataFrame back to a Pandas DataFrame
# ---> <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=66'>67</a> source_df = source_ddf.compute()
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=68'>69</a> # Rename columns in ref_subset by prepending target_col
#      <a href='vscode-notebook-cell:/Users/tlahtolli/dev/drone_warfare/data/cleanup/location_cleanup.ipynb#W3sZmlsZQ%3D%3D?line=69'>70</a> renamed_columns = {col: f'{target_col}_{col}' for col in ref_subset.columns}
#
# File /usr/local/lib/python3.9/site-packages/dask/base.py:314, in DaskMethodsMixin.compute(self, **kwargs)
#     290 def compute(self, **kwargs):
#     291     """Compute this dask collection
#     292
#     293     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     312     dask.base.compute
#     313     """
# --> 314     (result,) = compute(self, traverse=False, **kwargs)
#     315     return result
#
# File /usr/local/lib/python3.9/site-packages/dask/base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     596     keys.append(x.__dask_keys__())
#     597     postcomputes.append(x.__dask_postcompute__())
# --> 599 results = schedule(dsk, keys, **kwargs)
#     600 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /usr/local/lib/python3.9/site-packages/distributed/client.py:3168, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3166         should_rejoin = False
#    3167 try:
# -> 3168     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3169 finally:
#    3170     for f in futures.values():
#
# File /usr/local/lib/python3.9/site-packages/distributed/client.py:2328, in Client.gather(self, futures, errors, direct, asynchronous)
#    2326 else:
#    2327     local_worker = None
# -> 2328 return self.sync(
#    2329     self._gather,
#    2330     futures,
#    2331     errors=errors,
#    2332     direct=direct,
#    2333     local_worker=local_worker,
#    2334     asynchronous=asynchronous,
#    2335 )
#
# File /usr/local/lib/python3.9/site-packages/distributed/utils.py:345, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     343     return future
#     344 else:
# --> 345     return sync(
#     346         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     347     )
#
# File /usr/local/lib/python3.9/site-packages/distributed/utils.py:408, in sync(loop, func, callback_timeout, *args, **kwargs)
#     406 else:
#     407     while not e.is_set():
# --> 408         wait(10)
#     410 if error:
#     411     typ, exc, tb = error
#
# File /usr/local/lib/python3.9/site-packages/distributed/utils.py:397, in sync.<locals>.wait(timeout)
#     395 def wait(timeout):
#     396     try:
# --> 397         return e.wait(timeout)
#     398     except KeyboardInterrupt:
#     399         loop.add_callback(cancel)
#
# File /usr/local/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File /usr/local/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
